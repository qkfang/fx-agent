# %% [markdown]
# # Call Forex Trading Agent from Fabric
#
# This notebook invokes **Microsoft Agent Framework 1.0** agents using the **Foundry Agent Service v2** with the **OpenAI Responses API**.

# %%
# %pip install azure-ai-projects azure-identity
# Out:
# Requirement already satisfied: azure-ai-projects in c:\python\python314\lib\site-packages (2.0.1)
# Requirement already satisfied: azure-identity in c:\python\python314\lib\site-packages (1.25.3)
# Requirement already satisfied: isodate>=0.6.1 in c:\python\python314\lib\site-packages (from azure-ai-projects) (0.7.2)
# Requirement already satisfied: azure-core>=1.37.0 in c:\python\python314\lib\site-packages (from azure-ai-projects) (1.37.0)
# Requirement already satisfied: typing-extensions>=4.11 in c:\python\python314\lib\site-packages (from azure-ai-projects) (4.15.0)
# Requirement already satisfied: openai>=2.8.0 in c:\users\danielfang\appdata\roaming\python\python314\site-packages (from azure-ai-projects) (2.15.0)
# Requirement already satisfied: azure-storage-blob>=12.15.0 in c:\python\python314\lib\site-packages (from azure-ai-projects) (12.28.0)
# Requirement already satisfied: cryptography>=2.5 in c:\python\python314\lib\site-packages (from azure-identity) (46.0.3)
# Requirement already satisfied: msal>=1.35.1 in c:\python\python314\lib\site-packages (from azure-identity) (1.35.1)
# Requirement already satisfied: msal-extensions>=1.2.0 in c:\python\python314\lib\site-packages (from azure-identity) (1.3.1)
# Requirement already satisfied: requests>=2.21.0 in c:\python\python314\lib\site-packages (from azure-core>=1.37.0->azure-ai-projects) (2.32.5)
# Requirement already satisfied: cffi>=2.0.0 in c:\python\python314\lib\site-packages (from cryptography>=2.5->azure-identity) (2.0.0)
# Requirement already satisfied: pycparser in c:\python\python314\lib\site-packages (from cffi>=2.0.0->cryptography>=2.5->azure-identity) (2.23)
# Requirement already satisfied: PyJWT<3,>=1.0.0 in c:\python\python314\lib\site-packages (from PyJWT[crypto]<3,>=1.0.0->msal>=1.35.1->azure-identity) (2.10.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\python\python314\lib\site-packages (from requests>=2.21.0->azure-core>=1.37.0->azure-ai-projects) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\python\python314\lib\site-packages (from requests>=2.21.0->azure-core>=1.37.0->azure-ai-projects) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\python\python314\lib\site-packages (from requests>=2.21.0->azure-core>=1.37.0->azure-ai-projects) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\python\python314\lib\site-packages (from requests>=2.21.0->azure-core>=1.37.0->azure-ai-projects) (2026.1.4)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\danielfang\appdata\roaming\python\python314\site-packages (from openai>=2.8.0->azure-ai-projects) (4.12.1)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\danielfang\appdata\roaming\python\python314\site-packages (from openai>=2.8.0->azure-ai-projects) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\danielfang\appdata\roaming\python\python314\site-packages (from openai>=2.8.0->azure-ai-projects) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in c:\users\danielfang\appdata\roaming\python\python314\site-packages (from openai>=2.8.0->azure-ai-projects) (0.12.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\danielfang\appdata\roaming\python\python314\site-packages (from openai>=2.8.0->azure-ai-projects) (2.12.5)
# Requirement already satisfied: sniffio in c:\users\danielfang\appdata\roaming\python\python314\site-packages (from openai>=2.8.0->azure-ai-projects) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\danielfang\appdata\roaming\python\python314\site-packages (from openai>=2.8.0->azure-ai-projects) (4.67.1)
# Requirement already satisfied: httpcore==1.* in c:\users\danielfang\appdata\roaming\python\python314\site-packages (from httpx<1,>=0.23.0->openai>=2.8.0->azure-ai-projects) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\danielfang\appdata\roaming\python\python314\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai>=2.8.0->azure-ai-projects) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\danielfang\appdata\roaming\python\python314\site-packages (from pydantic<3,>=1.9.0->openai>=2.8.0->azure-ai-projects) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\danielfang\appdata\roaming\python\python314\site-packages (from pydantic<3,>=1.9.0->openai>=2.8.0->azure-ai-projects) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\danielfang\appdata\roaming\python\python314\site-packages (from pydantic<3,>=1.9.0->openai>=2.8.0->azure-ai-projects) (0.4.2)
# Requirement already satisfied: colorama in c:\users\danielfang\appdata\roaming\python\python314\site-packages (from tqdm>4->openai>=2.8.0->azure-ai-projects) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## Configuration

# %%
from azure.identity import DefaultAzureCredential
from azure.ai.projects import AIProjectClient

# Format: "https://resource_name.services.ai.azure.com/api/projects/project_name"
PROJECT_ENDPOINT = "https://fxag-foundry.services.ai.azure.com/api/projects/fxag-foundry-project"

project = AIProjectClient(
    endpoint=PROJECT_ENDPOINT,
    credential=DefaultAzureCredential(),
)

openai = project.get_openai_client()

# %% [markdown]
# Research Agent

# %%
import json

news_article = {
    "id": 4,
    "title": "US Expands Tariffs on Chinese Goods, Renewing Trade War Fears",
    "summary": "Washington's new 25% tariffs on Chinese tech exports send USD higher and EM currencies lower.",
    "content": "The United States announced sweeping new 25% tariffs on a broad range of Chinese-manufactured technology products, including electric vehicles, solar panels and advanced semiconductors. The move, framed as a national security measure, drew an immediate pledge of retaliation from Beijing. The US dollar index (DXY) jumped 0.7% as investors priced in a more restrictive global trade environment, while the offshore yuan weakened past 7.35 against the dollar — a level not seen since the 2022 peak. Emerging market currencies with close trade ties to China, including the Thai baht, South Korean won and Malaysian ringgit, fell sharply. Equity markets in Europe and Asia sold off, with tech-heavy indices leading losses on fears of supply-chain disruption. Strategists warn that a full-blown trade war could shave 0.5–0.8 percentage points from global GDP growth in 2026.",
    "type": "Bad",
    "category": "Macro",
    "publishedDate": "2026-03-16T10:15:00",
    "author": "FX News Team",
    "isPublished": True,
    "publishedAt": "2026-03-16T10:20:00",
    "source": "FX News Centre"
}

# Create analysis request
analysis_request = f"""
Please analyze the following news article and provide insights on its impact on forex markets. then create research draft.

{json.dumps(news_article, indent=2)}

"""

response = openai.responses.create(
    extra_body={
        "agent_reference": {
            "name": "fxag-research",
            "type": "agent_reference",
        }
    },
    input=analysis_request,
)

print(response.output_text)

# %% [markdown]
# Suggestion Agent

# %%
import json

news_article = {
    "id": 4,
    "title": "US Expands Tariffs on Chinese Goods, Renewing Trade War Fears",
    "summary": "Washington's new 25% tariffs on Chinese tech exports send USD higher and EM currencies lower.",
    "content": "The United States announced sweeping new 25% tariffs on a broad range of Chinese-manufactured technology products, including electric vehicles, solar panels and advanced semiconductors. The move, framed as a national security measure, drew an immediate pledge of retaliation from Beijing. The US dollar index (DXY) jumped 0.7% as investors priced in a more restrictive global trade environment, while the offshore yuan weakened past 7.35 against the dollar — a level not seen since the 2022 peak. Emerging market currencies with close trade ties to China, including the Thai baht, South Korean won and Malaysian ringgit, fell sharply. Equity markets in Europe and Asia sold off, with tech-heavy indices leading losses on fears of supply-chain disruption. Strategists warn that a full-blown trade war could shave 0.5–0.8 percentage points from global GDP growth in 2026.",
    "type": "Bad",
    "category": "Macro",
    "publishedDate": "2026-03-16T10:15:00",
    "author": "FX News Team",
    "isPublished": True,
    "publishedAt": "2026-03-16T10:20:00",
    "source": "FX News Centre"
}


# Create analysis request
analysis_request = f"""
who is the customer to suggest?

{json.dumps(news_article, indent=2)}

"""

response = openai.responses.create(
    extra_body={
        "agent_reference": {
            "name": "fxag-suggestion",
            "type": "agent_reference",
        }
    },
    input=analysis_request,
)

print(response.output_text)
# Out:
# Step 1: Parsing the research note for key FX implications, then I’ll pull customers and trader data to identify who should be contacted.Step 2–3 complete: I identified customers with portfolios exposed to currencies mentioned in the note, especially USD, CNH, KRW, and broadly China-sensitive FX. Next I’m retrieving their preferences and then matching them to suitable traders.Here’s the structured recommendation.
#
# ## 1) Research note summary
# **Insight:**
# The note is **bullish USD** and **bearish CNH / China-sensitive EM Asia FX** after new US tariffs on Chinese goods.
# Key impacted currencies/pairs from the note:
#
# - **USD**: bullish
# - **USD/CNH**: bullish
# - **USD/KRW**: bullish bias implied
# - Also negative for **THB, KRW, MYR** and generally for China-linked risk currencies
# - Broader risk-off tone may also pressure **AUD/USD**
#
# **Sentiment:** Bearish macro / risk-off.
#
# ---
#
# ## 2) Customers to contact
#
# ### Primary customer to suggest: **Diana Chen**
# **Customer ID:** 3
# **Company:** Asia Macro Fund
#
# **Why she is the strongest match:**
# - She has an **open USD/CNH position**
# - Her position is **Sell USD/CNH**, while the note implies **USD/CNH should rise**
# - That means her current position is **directly at risk**
# - Her preferences strongly overlap with the note:
#   - Preferred pairs: **USD/CNH, AUD/NZD**
#   - Risk tolerance: **High**
#   - Trading style: **Swing**
# - This is the clearest and most actionable outreach candidate
#
# **Relevant position:**
# - **USD/CNH – Sell – 300,000 – Open**
# - Research view suggests this position faces adverse pressure as CNH weakens and USD strengthens
#
# **Suggested trader:** **Kenji Tanaka**
# - **Specialization:** JPY, **CNH, KRW**
# - **Region:** Asia Pacific
# He is the best fit by both pair expertise and regional relevance.
#
# **Suggested talking points:**
# - Tariff escalation is reinforcing **USD strength and offshore yuan weakness**
# - USD/CNH breaking above 7.35 suggests pressure may persist
# - Her current **short USD/CNH** exposure is vulnerable
# - Discuss:
#   - reducing or hedging short USD/CNH risk
#   - tactical reversal into **long USD/CNH**
#   - protecting against further trade-war-driven CNH weakness
# - Secondary angle: monitor spillover into broader Asia risk sentiment
#
# ---
#
# ### Secondary customer: **Grace Park**
# **Customer ID:** 6
# **Company:** Seoul Wealth Mgmt
#
# **Why relevant:**
# - She has direct exposure to **USD/KRW**
# - The note explicitly highlights weakness in the **South Korean won**
# - Her open position is **Sell USD/KRW**, which is vulnerable if USD rises versus KRW
# - Preferences align:
#   - Preferred pairs: **USD/KRW, GBP/JPY**
#   - Risk tolerance: **High**
#   - Trading style: **Scalp**
#
# **Relevant position:**
# - **USD/KRW – Sell – 150,000 – Open**
# - Research note implies **USD/KRW upside**, so her position is negatively affected
#
# **Suggested trader:** **Kenji Tanaka**
# - Best match due to **KRW specialization** and **Asia Pacific** region
#
# **Suggested talking points:**
# - KRW is under pressure due to China-linked trade exposure
# - Her **short USD/KRW** is exposed to continued risk-off repricing
# - Given her scalp style, discuss:
#   - tightening stops
#   - reducing downside exposure quickly
#   - tactical long USD/KRW opportunities on momentum
# - Watch for follow-through from broader EM Asia selling
#
# ---
#
# ### Tertiary customer: **Bob Smith**
# **Customer ID:** 1
# **Company:** Pacific Investments
#
# **Why relevant:**
# - He has an open **AUD/USD** position
# - While not explicitly named in the note, AUD is often pressured by **China slowdown / trade-war fears**
# - His position is **Buy AUD/USD**, which may be vulnerable in a stronger USD / risk-off environment
# - Preference overlap:
#   - Preferred pairs: **USD/JPY, AUD/USD**
#   - Risk tolerance: **Medium**
#   - Trading style: **Day**
#
# **Relevant position:**
# - **AUD/USD – Buy – 50,000 – Open**
# - This is indirectly negatively affected by the note
#
# **Suggested trader:** **Kenji Tanaka**
# - Best active fit for Asia-linked macro themes
# - Aisha Patel has AUD specialization but is **inactive**
#
# **Suggested talking points:**
# - Trade-war fears may spill over into **AUD weakness**
# - Stronger DXY creates headwinds for AUD/USD longs
# - For a day trader, discuss:
#   - tactical downside risk in AUD/USD
#   - near-term support levels
#   - reducing long exposure or trading short-term rebounds selectively
#
# ---
#
# ## 3) Best single customer to suggest
# If you want **one customer only**, the best suggestion is:
#
# # **Diana Chen**
#
# **Reason:**
# She has the most direct exposure to the research call via an **open short USD/CNH position**, and the note is explicitly **bullish USD/CNH**. This is the highest-conviction outreach opportunity.
#
# ## 4) Best trader for outreach
# # **Kenji Tanaka**
# Because he specializes in **CNH and KRW** and covers **Asia Pacific**, making him the ideal trader to contact Diana Chen and Grace Park.
#
# If you want, I can also turn this into a **ranked top-3 outreach list** in a compact table.

# %% [markdown]
# Trader Agent

# %%
import json

# Create analysis request
analysis_request = f"""
what's last transaction? 

create a new transaction with the following details:
- Pair: AUD/USD
- Amount: 100,000
- Side: Buy

"""

response = openai.responses.create(
    extra_body={
        "agent_reference": {
            "name": "fxag-trader",
            "type": "agent_reference",
        }
    },
    input=analysis_request,
)

print(response.output_text)
# Out:
# The last transaction was:
#
# - ID: 17
# - Pair: AUD/USD
# - Side: Buy
# - Amount: 10,000
# - Rate: 0.6515846128300061
# - Total: 6,515.85 USD
# - Time: 2026-03-22 05:59:44 UTC
#
# I can see the requested new transaction details:
# - Pair: AUD/USD
# - Amount: 100,000
# - Side: Buy
#
# But I don’t currently have a tool available here to create/execute a transaction. If you want, I can still help you:
# - verify whether this order size fits the fund balance, or
# - format the order clearly for manual entry.

# %% [markdown]
# Insight Agent

# %%
import json

# Create analysis request
analysis_request = f"""
why chinese market is slowing down?
"""

response = openai.responses.create(
    extra_body={
        "agent_reference": {
            "name": "fxag-insight",
            "type": "agent_reference",
        }
    },
    input=analysis_request,
)

print(response.output_text)
