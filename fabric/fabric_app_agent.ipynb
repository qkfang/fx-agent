# %% [markdown]
# # Call Forex Trading Agent from Fabric
#
# This notebook invokes **Microsoft Agent Framework 1.0** agents using the **Foundry Agent Service v2** with the **OpenAI Responses API**.

# %%
# %pip install azure-ai-projects azure-identity
# Out:
# Requirement already satisfied: azure-ai-projects in c:\python\python314\lib\site-packages (2.0.1)
# Requirement already satisfied: azure-identity in c:\python\python314\lib\site-packages (1.25.3)
# Requirement already satisfied: isodate>=0.6.1 in c:\python\python314\lib\site-packages (from azure-ai-projects) (0.7.2)
# Requirement already satisfied: azure-core>=1.37.0 in c:\python\python314\lib\site-packages (from azure-ai-projects) (1.37.0)
# Requirement already satisfied: typing-extensions>=4.11 in c:\python\python314\lib\site-packages (from azure-ai-projects) (4.15.0)
# Requirement already satisfied: openai>=2.8.0 in c:\users\danielfang\appdata\roaming\python\python314\site-packages (from azure-ai-projects) (2.15.0)
# Requirement already satisfied: azure-storage-blob>=12.15.0 in c:\python\python314\lib\site-packages (from azure-ai-projects) (12.28.0)
# Requirement already satisfied: cryptography>=2.5 in c:\python\python314\lib\site-packages (from azure-identity) (46.0.3)
# Requirement already satisfied: msal>=1.35.1 in c:\python\python314\lib\site-packages (from azure-identity) (1.35.1)
# Requirement already satisfied: msal-extensions>=1.2.0 in c:\python\python314\lib\site-packages (from azure-identity) (1.3.1)
# Requirement already satisfied: requests>=2.21.0 in c:\python\python314\lib\site-packages (from azure-core>=1.37.0->azure-ai-projects) (2.32.5)
# Requirement already satisfied: cffi>=2.0.0 in c:\python\python314\lib\site-packages (from cryptography>=2.5->azure-identity) (2.0.0)
# Requirement already satisfied: pycparser in c:\python\python314\lib\site-packages (from cffi>=2.0.0->cryptography>=2.5->azure-identity) (2.23)
# Requirement already satisfied: PyJWT<3,>=1.0.0 in c:\python\python314\lib\site-packages (from PyJWT[crypto]<3,>=1.0.0->msal>=1.35.1->azure-identity) (2.10.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\python\python314\lib\site-packages (from requests>=2.21.0->azure-core>=1.37.0->azure-ai-projects) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\python\python314\lib\site-packages (from requests>=2.21.0->azure-core>=1.37.0->azure-ai-projects) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\python\python314\lib\site-packages (from requests>=2.21.0->azure-core>=1.37.0->azure-ai-projects) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\python\python314\lib\site-packages (from requests>=2.21.0->azure-core>=1.37.0->azure-ai-projects) (2026.1.4)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\danielfang\appdata\roaming\python\python314\site-packages (from openai>=2.8.0->azure-ai-projects) (4.12.1)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\danielfang\appdata\roaming\python\python314\site-packages (from openai>=2.8.0->azure-ai-projects) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\danielfang\appdata\roaming\python\python314\site-packages (from openai>=2.8.0->azure-ai-projects) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in c:\users\danielfang\appdata\roaming\python\python314\site-packages (from openai>=2.8.0->azure-ai-projects) (0.12.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\danielfang\appdata\roaming\python\python314\site-packages (from openai>=2.8.0->azure-ai-projects) (2.12.5)
# Requirement already satisfied: sniffio in c:\users\danielfang\appdata\roaming\python\python314\site-packages (from openai>=2.8.0->azure-ai-projects) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\danielfang\appdata\roaming\python\python314\site-packages (from openai>=2.8.0->azure-ai-projects) (4.67.1)
# Requirement already satisfied: httpcore==1.* in c:\users\danielfang\appdata\roaming\python\python314\site-packages (from httpx<1,>=0.23.0->openai>=2.8.0->azure-ai-projects) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\danielfang\appdata\roaming\python\python314\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai>=2.8.0->azure-ai-projects) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\danielfang\appdata\roaming\python\python314\site-packages (from pydantic<3,>=1.9.0->openai>=2.8.0->azure-ai-projects) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\danielfang\appdata\roaming\python\python314\site-packages (from pydantic<3,>=1.9.0->openai>=2.8.0->azure-ai-projects) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\danielfang\appdata\roaming\python\python314\site-packages (from pydantic<3,>=1.9.0->openai>=2.8.0->azure-ai-projects) (0.4.2)
# Requirement already satisfied: colorama in c:\users\danielfang\appdata\roaming\python\python314\site-packages (from tqdm>4->openai>=2.8.0->azure-ai-projects) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## Configuration

# %%
from azure.identity import DefaultAzureCredential
from azure.ai.projects import AIProjectClient

# Format: "https://resource_name.services.ai.azure.com/api/projects/project_name"
PROJECT_ENDPOINT = "https://fxag-foundry.services.ai.azure.com/api/projects/fxag-foundry-project"

project = AIProjectClient(
    endpoint=PROJECT_ENDPOINT,
    credential=DefaultAzureCredential(),
)

openai = project.get_openai_client()

# %% [markdown]
# ## Simple Query - Get Current Quote

# %%
# Non-streaming response with news analysis
news_article = {
    "title": "US Expands Tariffs on Chinese Goods, Renewing Trade War Fears",
    "summary": "Washington's new 25% tariffs on Chinese tech exports send USD higher and EM currencies lower.",
    "content": "The United States announced sweeping new 25% tariffs on a broad range of Chinese-manufactured technology products, including electric vehicles, solar panels and advanced semiconductors. The move, framed as a national security measure, drew an immediate pledge of retaliation from Beijing. The US dollar index (DXY) jumped 0.7% as investors priced in a more restrictive global trade environment, while the offshore yuan weakened past 7.35 against the dollar — a level not seen since the 2022 peak. Emerging market currencies with close trade ties to China, including the Thai baht, South Korean won and Malaysian ringgit, fell sharply. Equity markets in Europe and Asia sold off, with tech-heavy indices leading losses on fears of supply-chain disruption. Strategists warn that a full-blown trade war could shave 0.5–0.8 percentage points from global GDP growth in 2026.",
    "type": "Bad",
    "category": "Macro",
    "publishedDate": "2026-03-16T10:15:00",
    "author": "FX News Team",
    "isPublished": True,
    "publishedAt": "2026-03-16T10:20:00",
    "source": "FX News Centre"
}

import json
import requests

# Create analysis request
analysis_request = f"""
Please analyze the following news article and provide insights on its impact on forex markets:

{json.dumps(news_article, indent=2)}

Provide a comprehensive analysis and save the analysis as draft search in the database
"""

# Call the research agent endpoint
RESEARCH_AGENT_URL = "http://localhost:5001/research"

response = requests.post(
    RESEARCH_AGENT_URL,
    json={"message": analysis_request},
    headers={"Content-Type": "application/json"}
)

if response.status_code == 200:
    result = response.json()
    print(result.get("response", "No response received"))
else:
    print(f"Error: {response.status_code} - {response.text}")
# Out:
# **Analysis of "US Expands Tariffs on Chinese Goods, Renewing Trade War Fears" and Forex Market Impact**
#
# **Headline Summary**
# The US announced broad 25% tariffs on Chinese technology exports, targeting EVs, solar panels, and advanced semiconductors. The announcement was met with a strong USD rally and broad selling in emerging market (EM) currencies, especially those closely linked to Chinese trade.
#
# ---
#
# **Forex Market Implications**
#
# **1. US Dollar (USD)**
# The immediate 0.7% spike in the US Dollar Index (DXY) indicates strong safe-haven demand and expectations of tighter global financial conditions. Historically, USD outperforms in risk-off environments, especially when global growth concerns mount. The renewed trade tensions raise the probability of capital flows returning to US assets in search of safety and liquidity.
#
# **Tactical Insight:**
# Short-term, further USD appreciation is likely, especially versus Asian and EM FX.
#
# ---
#
# **2. Chinese Yuan (CNY, CNH)**
# The offshore yuan (CNH) swiftly breached the 7.35 level, highlighting market anxiety over China’s export outlook and potential economic deceleration. While the PBoC can intervene to moderate volatility, structural depreciation pressure is intensifying as the trade outlook darkens.
#
# **Tactical Insight:**
# Expect continued yuan weakness. Options markets likely to price in higher vol and downside risk.
# Watch for possible intervention, but the macro trend is negative.
#
# ---
#
# **3. Emerging Market Asia FX (THB, KRW, MYR)**
# The Thai baht, South Korean won, and Malaysian ringgit fell sharply, reflecting their trade dependency on China and exposure to global supply chains. Renewed trade war risks could compound vulnerabilities from slower global growth and capital outflows.
#
# **Tactical Insight:**
# Short/underweight EM Asia FX, especially currencies with high China trade correlations.
# Monitor for policy responses from Asian central banks, but defensive positioning advised.
#
# ---
#
# **4. Risk Appetite & Cross-Asset Implications**
# Selloff in Asian and European equities, led by tech indices, reinforces the risk-off narrative. High-beta and carry currencies may face further headwinds.
# Currencies like the Japanese yen (JPY) and Swiss franc (CHF) may attract safe-haven flows.
#
# ---
#
# **5. Macro Risks**
# Strategists’ warnings that global GDP growth could slow by 0.5–0.8 percentage points by 2026 underscore the broader economic threat. If tit-for-tat tariffs escalate, expect further downward pressure on trade-sensitive FX and potential policy pivots from central banks.
#
# ---
#
# **FX Market Strategy Recommendations**
# - Maintain long USD positions vs. EM Asia in the near term.
# - Consider tactical longs in safe-haven FX (JPY, CHF).
# - Avoid or hedge CNY, CNH, and China-correlated EM FX.
# - Monitor for escalation signals, including China’s retaliatory tariff announcements and central bank interventions.
#
# ---
#
# **Conclusion**
# US tariff escalation on China revives trade war anxieties, with immediate bullish implications for the USD and bearish pressure on the yuan, EM Asian FX, and risk-sensitive currencies. Monitor further headlines for confirmation or escalation of retaliation measures.
#
# ---
#
# Proceeding to save this analysis as a draft research note.
#
# ---
#
# Now using tool: `create_research_draft`.
# create_research_draft
# {
#   "title": "US Expands Tariffs on Chinese Goods: FX Market Implications and Strategies",
#   "summary": "The US's sweeping new tariffs on Chinese tech exports have bolstered the USD and pressured Asian and emerging market currencies. This analysis outlines the FX impact and provides tactical recommendations.",
#   "content": "**Headline Summary**\nThe US imposed 25% tariffs on a range of Chinese technology exports, including EVs and semiconductors, sparking a swift USD rally and broad emerging market currency declines.\n\n**US Dollar (USD):**\nThe DXY's 0.7% jump signals flight-to-safety and rising risk aversion. USD strength against EM and Asian FX should persist as global growth expectations deteriorate.\n\n**Chinese Yuan (CNY, CNH):**\nThe offshore yuan weakening past 7.35 reflects significant pressures, with the risk of further depreciation if trade tensions worsen. Some PBoC intervention is possible, but the outlook remains bearish.\n\n**Emerging Market Asia FX (THB, KRW, MYR):**\nThe Thai baht, South Korean won, and Malaysian ringgit all declined sharply. These currencies are likely to see further pressure due to high trade linkages with China and increased capital outflows.\n\n**Risk Appetite:**\nSelloffs in Asian and European equity markets reinforce broader risk aversion. Safe-haven FX such as the JPY and CHF could benefit.\n\n**Macro Risks:**\nA protracted trade conflict could shave 0.5–0.8pp from global GDP growth by 2026, deepening losses in trade-dependent currencies.\n\n**Recommendations:**\n- Stay long USD vs. EM Asia FX in the short term; consider tactical JPY and CHF longs.\n- Avoid/hedge CNY, CNH, and China-linked EM FX baskets.\n- Monitor escalation on both sides, especially retaliatory policies from China.\n\n**Conclusion:**\nUS tariff escalation has immediate bearish implications for Asian/EM FX and supports the USD and safe havens. Watch for further trade policy headlines and possible central bank responses.",
#   "category": "Macro",
#   "tags": ["USD", "CNY", "Emerging Markets", "Trade War", "USDJPY", "USDTHB", "USDKRW", "FX Strategy"],
#   "relatedNewsId": 4
# }
# The analysis has been successfully saved as a draft research note.
# **Article ID:** 4
#
# If you need this draft retrieved, revised, or expanded with additional data or currency pair insights, please specify your requirements.
